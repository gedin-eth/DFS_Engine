# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('DKEntries24JAN20.csv',
                   usecols= ['Contest Name','Contest ID', 'Entry Fee'])
line = pd.read_csv('trial.csv')
plain = pd.read_fwf('DKEntries24JAN20.csv', )

# %%
plain
# Out:
#      E
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# ..  ..
# 336  ,
# 337  ,
# 338  ,
# 339  ,
# 340  ,
#
# [341 rows x 1 columns]

# %%
line.drop(['Unnamed: 0', 'Budget', 'FPPG'],axis =1, inplace =True)

# %%
c1 = line.transpose()
c2 = data.transpose()
c3 = c2.append(c1)
c4 = c3.transpose()

# %%
c4[:30]
# Out:
#                               Contest Name   Contest ID Entry Fee  \
# 0   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 1   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 2   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 3   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 4   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 5   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 6   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 7   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 8   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 9   NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 10  NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 11  NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# 12  NBA $10K Quarter Jukebox [Just $0.25!]  8.51499e+07     $0.25
# ...
